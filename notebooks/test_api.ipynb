# %%
import requests
from src.todoist_exporter import TodoistToObsidian

todoist_app = TodoistToObsidian()

# %%
response = requests.get(f"{todoist_app.rest_url}/projects", headers=todoist_app.headers)
response.json()
# Out:
# [{'id': '2294435712',
#   'parent_id': None,
#   'order': 0,
#   'color': 'grey',
#   'name': 'Inbox',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': True,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6JHcQpWJJgcRmvPG',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2318631312',
#   'parent_id': None,
#   'order': 0,
#   'color': 'charcoal',
#   'name': 'Notes',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6QP5RMm4WVRg38F8',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2349465762',
#   'parent_id': None,
#   'order': 1,
#   'color': 'red',
#   'name': 'Get Tech',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XMCWC5w7CRJWRMM',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2349538611',
#   'parent_id': '2349465762',
#   'order': 2,
#   'color': 'red',
#   'name': 'RPRT Semanal Refact',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XMRQ5m8gvJ2RMcM',
#   'view_style': 'board',
#   'description': ''},
#  {'id': '2349466696',
#   'parent_id': '2349465762',
#   'order': 3,
#   'color': 'red',
#   'name': 'Datalake BR',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XMCgvjCHRQjfv4j',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2349466713',
#   'parent_id': '2349465762',
#   'order': 4,
#   'color': 'red',
#   'name': 'Billing LATAM',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XMCh2C2r2VvjJ3x',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2350049560',
#   'parent_id': '2349465762',
#   'order': 5,
#   'color': 'charcoal',
#   'name': 'Chargeback_detetails_CL',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XQX5XMVwF2jFWCf',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2349449389',
#   'parent_id': None,
#   'order': 6,
#   'color': 'berry_red',
#   'name': 'PKM',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XM8PgVG3WjHvrmG',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2344619603',
#   'parent_id': None,
#   'order': 7,
#   'color': 'teal',
#   'name': 'Augusto',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6WpFMrhW53fr7wMW',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2349721218',
#   'parent_id': '2344619603',
#   'order': 8,
#   'color': 'teal',
#   'name': 'TCC',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XP9CJPrg2hjwghV',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2349464658',
#   'parent_id': '2344619603',
#   'order': 9,
#   'color': 'berry_red',
#   'name': 'Entregar Apto',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': True,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XMCJRj67JMX48M6',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2348707749',
#   'parent_id': None,
#   'order': 10,
#   'color': 'teal',
#   'name': 'FUN',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XG65v6fpgMwgmrR',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2348690268',
#   'parent_id': None,
#   'order': 11,
#   'color': 'grape',
#   'name': 'Compras',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XG4hv577Hmfp4w3',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2304056439',
#   'parent_id': None,
#   'order': 12,
#   'color': 'blue',
#   'name': 'Learning',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6MV8pJ6jq6pRwjgg',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2349467825',
#   'parent_id': None,
#   'order': 13,
#   'color': 'blue',
#   'name': 'Python',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XMCrPgQv265PjqV',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2336853968',
#   'parent_id': None,
#   'order': 14,
#   'color': 'green',
#   'name': 'Ultra-aprendizado',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6VqJ5XQVVQhGc5Jc',
#   'view_style': 'list',
#   'description': ''},
#  {'id': '2350050235',
#   'parent_id': None,
#   'order': 15,
#   'color': 'charcoal',
#   'name': '2503Q04_rprt_semanal_improv',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://app.todoist.com/app/project/6XQX96xMVJXgjF2r',
#   'view_style': 'list',
#   'description': ''}]

# %%
#     {'id': '2349449389',
#       'parent_id': None,
#       'order': 6,
#       'color': 'berry_red',
#       'name': 'PKM',
#       'comment_count': 0,
#       'is_shared': False,
#       'is_favorite': False,
#       'is_inbox_project': False,
#       'is_team_inbox': False,
#       'url': 'https://app.todoist.com/app/project/6XM8PgVG3WjHvrmG',
#       'view_style': 'list',
#       'description': ''}
response = requests.get(f"{todoist_app.rest_url}/tasks", headers=todoist_app.headers, params = {
        "project_id": 2349449389,
    })
response.json()
# Out:
# [{'id': '8675796902',
#   'assigner_id': None,
#   'assignee_id': None,
#   'project_id': '2349449389',
#   'section_id': None,
#   'parent_id': None,
#   'order': 2,
#   'content': 'Registro preocupação trabalho (e não trabalho) Processar',
#   'description': '',
#   'is_completed': False,
#   'labels': ['PKM', 'tdah', '🗒'],
#   'priority': 4,
#   'comment_count': 0,
#   'creator_id': '40207464',
#   'created_at': '2024-12-12T23:02:21.575373Z',
#   'due': None,
#   'url': 'https://app.todoist.com/app/task/8675796902',
#   'duration': None,
#   'deadline': None},
#  {'id': '8924994174',
#   'assigner_id': None,
#   'assignee_id': None,
#   'project_id': '2349449389',
#   'section_id': None,
#   'parent_id': None,
#   'order': 3,
#   'content': 'Criar processo de encerramento de Projeto',
#   'description': '',
#   'is_completed': False,
#   'labels': [],
#   'priority': 1,
#   'comment_count': 0,
#   'creator_id': '40207464',
#   'created_at': '2025-02-27T23:50:58.057995Z',
#   'due': None,
#   'url': 'https://app.todoist.com/app/task/8924994174',
#   'duration': None,
#   'deadline': None},
#  {'id': '8925415775',
#   'assigner_id': None,
#   'assignee_id': None,
#   'project_id': '2349449389',
#   'section_id': None,
#   'parent_id': None,
#   'order': 4,
#   'content': 'Explorar DB Folder',
#   'description': '',
#   'is_completed': False,
#   'labels': ['PKM'],
#   'priority': 3,
#   'comment_count': 0,
#   'creator_id': '40207464',
#   'created_at': '2025-02-28T04:49:50.620577Z',
#   'due': {'date': '2025-03-07',
#    'string': '7 mar',
#    'lang': 'pt',
#    'is_recurring': False},
#   'url': 'https://app.todoist.com/app/task/8925415775',
#   'duration': None,
#   'deadline': {'date': '2025-03-05', 'lang': 'pt'}},
#  {'id': '8944611544',
#   'assigner_id': None,
#   'assignee_id': None,
#   'project_id': '2349449389',
#   'section_id': None,
#   'parent_id': None,
#   'order': 5,
#   'content': 'Add rotinas',
#   'description': '',
#   'is_completed': False,
#   'labels': ['PKM'],
#   'priority': 1,
#   'comment_count': 0,
#   'creator_id': '40207464',
#   'created_at': '2025-03-06T01:12:13.172352Z',
#   'due': None,
#   'url': 'https://app.todoist.com/app/task/8944611544',
#   'duration': None,
#   'deadline': None},
#  {'id': '8946341417',
#   'assigner_id': None,
#   'assignee_id': None,
#   'project_id': '2349449389',
#   'section_id': None,
#   'parent_id': None,
#   'order': 6,
#   'content': 'flashcards and reviews plan (vocabulary and notes)',
#   'description': '',
#   'is_completed': False,
#   'labels': ['PKM'],
#   'priority': 3,
#   'comment_count': 0,
#   'creator_id': '40207464',
#   'created_at': '2025-03-06T14:05:23.765960Z',
#   'due': {'date': '2025-03-06',
#    'string': '6 Mar 21:00',
#    'lang': 'pt',
#    'is_recurring': False,
#    'datetime': '2025-03-06T21:00:00'},
#   'url': 'https://app.todoist.com/app/task/8946341417',
#   'duration': None,
#   'deadline': {'date': '2025-03-07', 'lang': 'pt'}}]

# %%
response = requests.get(f"{todoist_app.rest_url}/sections", headers=todoist_app.headers, params = {
        "project_id": 2349449389,
    })
response.json()
# Out:
# [{'id': '183950338',
#   'v2_id': '6XM8Qpgqcrp6vg4G',
#   'project_id': '2349449389',
#   'v2_project_id': '6XM8PgVG3WjHvrmG',
#   'order': 1,
#   'name': 'Education'},
#  {'id': '183950431',
#   'v2_id': '6XM8QxJRWH3r2QwG',
#   'project_id': '2349449389',
#   'v2_project_id': '6XM8PgVG3WjHvrmG',
#   'order': 2,
#   'name': 'Vault'},
#  {'id': '183959614',
#   'v2_id': '6XM94h2XWMw2RqWp',
#   'project_id': '2349449389',
#   'v2_project_id': '6XM8PgVG3WjHvrmG',
#   'order': 3,
#   'name': 'Integrations'},
#  {'id': '183962656',
#   'v2_id': '6XM9GFwJv7P8x55p',
#   'project_id': '2349449389',
#   'v2_project_id': '6XM8PgVG3WjHvrmG',
#   'order': 4,
#   'name': 'Plugins'},
#  {'id': '183962638',
#   'v2_id': '6XM9G7jvvXwqW5pp',
#   'project_id': '2349449389',
#   'v2_project_id': '6XM8PgVG3WjHvrmG',
#   'order': 5,
#   'name': 'Plugins/maybe'}]

# %%
response = requests.get(f"https://api.todoist.com/sync/v9/completed/get_all", headers=todoist_app.headers, params = {
        "project_id": 2349449389,
    })
response.json()
# Out:
# {'items': [{'completed_at': '2025-02-24T02:02:49.000000Z',
#    'content': 'Set Flash cards system @PKM',
#    'id': '8101176156',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': None,
#    'task_id': '8858879201',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': None,
#    'v2_task_id': '6XFMhJ4W587Gvfj4'},
#   {'completed_at': '2025-02-24T01:30:39.000000Z',
#    'content': 'creat flow to pass todoist done projectgs to Obsidian (log) @PKM',
#    'id': '8101125565',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': None,
#    'task_id': '8909514159',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': None,
#    'v2_task_id': '6XM8jWx7rpVP548p'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] Excalidraw',
#    'id': '8100839744',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962638',
#    'task_id': '8909735017',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9G7jvvXwqW5pp',
#    'v2_task_id': '6XM9GCQH2JcG8hgp'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] ExcaliBrain',
#    'id': '8100839734',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962638',
#    'task_id': '8909735012',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9G7jvvXwqW5pp',
#    'v2_task_id': '6XM9GCMmFc8m8R8G'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] File Color',
#    'id': '8100839720',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962638',
#    'task_id': '8909735006',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9G7jvvXwqW5pp',
#    'v2_task_id': '6XM9GCQjr3GQ82JG'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] Tracker',
#    'id': '8100839712',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962638',
#    'task_id': '8909735002',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9G7jvvXwqW5pp',
#    'v2_task_id': '6XM9GCPqgfC97v7G'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] Periodic notes',
#    'id': '8100839681',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962638',
#    'task_id': '8909734998',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9G7jvvXwqW5pp',
#    'v2_task_id': '6XM9GCHq7qRrfq7p'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': 'Calendar',
#    'id': '8100839672',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962638',
#    'task_id': '8909734990',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9G7jvvXwqW5pp',
#    'v2_task_id': '6XM9GCHGrVhcMjvp'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] Custom File Explorer sorting',
#    'id': '8100839661',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962656',
#    'task_id': '8909734507',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9GFwJv7P8x55p',
#    'v2_task_id': '6XM9G8RX9P6VHJxp'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] Editing toolbar',
#    'id': '8100839647',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962656',
#    'task_id': '8909734498',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9GFwJv7P8x55p',
#    'v2_task_id': '6XM9G8RGRXjr676G'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] QuickAdd',
#    'id': '8100839637',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962656',
#    'task_id': '8909734491',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9GFwJv7P8x55p',
#    'v2_task_id': '6XM9G8JRfGpR6JCG'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] Templater',
#    'id': '8100839631',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962656',
#    'task_id': '8909734484',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9GFwJv7P8x55p',
#    'v2_task_id': '6XM9G8JJXRGX6PFG'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] DB Folders',
#    'id': '8100839613',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962656',
#    'task_id': '8909734479',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9GFwJv7P8x55p',
#    'v2_task_id': '6XM9G8MVwppFXXQp'},
#   {'completed_at': '2025-02-23T22:37:56.000000Z',
#    'content': '[x] Dataview',
#    'id': '8100839601',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183962656',
#    'task_id': '8909734474',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM9GFwJv7P8x55p',
#    'v2_task_id': '6XM9G8P4MwHWcWmp'},
#   {'completed_at': '2025-02-23T22:24:33.000000Z',
#    'content': '[ ] Set Askify integration',
#    'id': '8100814059',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183959614',
#    'task_id': '8909642224',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM94h2XWMw2RqWp',
#    'v2_task_id': '6XM94hMMqGJRcHPp'},
#   {'completed_at': '2025-02-23T22:24:32.000000Z',
#    'content': '[ ] Set raindrop integration',
#    'id': '8100814041',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183959614',
#    'task_id': '8909642215',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM94h2XWMw2RqWp',
#    'v2_task_id': '6XM94hJhcH9jjxFG'},
#   {'completed_at': '2025-02-23T22:24:29.000000Z',
#    'content': 'Canvas',
#    'id': '8100813953',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950338',
#    'task_id': '8909519745',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8Qpgqcrp6vg4G',
#    'v2_task_id': '6XM8jwx6p6cqXQwp'},
#   {'completed_at': '2025-02-23T21:52:17.000000Z',
#    'content': '[ ] Set todoist integration',
#    'id': '8100746673',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183959614',
#    'task_id': '8909642237',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM94h2XWMw2RqWp',
#    'v2_task_id': '6XM94hJ34GwfvjvG'},
#   {'completed_at': '2025-02-23T21:48:31.000000Z',
#    'content': '[ ] Home',
#    'id': '8100739110',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395945',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8Qxr66GG3r3Mp'},
#   {'completed_at': '2025-02-23T20:50:28.000000Z',
#    'content': '[ ] Track Template',
#    'id': '8100611194',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395936',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8QxmH8XxPf74G'},
#   {'completed_at': '2025-02-23T20:13:18.000000Z',
#    'content': '[ ] Project Template',
#    'id': '8100527803',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395930',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8QxmwrcJ95Q9G'},
#   {'completed_at': '2025-02-23T20:13:16.000000Z',
#    'content': '[ ] Notes Tramplate',
#    'id': '8100527759',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395916',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8QxjMrWVCF4qG'},
#   {'completed_at': '2025-02-23T20:13:15.000000Z',
#    'content': '[ ] Task management',
#    'id': '8100527702',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395909',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8QxmQ74m9Prjp'},
#   {'completed_at': '2025-02-23T20:13:09.000000Z',
#    'content': '[ ] Projects',
#    'id': '8100527524',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395905',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8Qxhc78m82C4p'},
#   {'completed_at': '2025-02-23T19:59:48.000000Z',
#    'content': '[x] Daily Note',
#    'id': '8100497189',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395900',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8QxhgR9PRqRgp'},
#   {'completed_at': '2025-02-23T19:59:46.000000Z',
#    'content': '[x] Propose vault organization and workflow',
#    'id': '8100497108',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950431',
#    'task_id': '8909395885',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8QxJRWH3r2QwG',
#    'v2_task_id': '6XM8Qxg4gCQfpjFp'},
#   {'completed_at': '2025-02-23T19:59:25.000000Z',
#    'content': '[x] ACCESS',
#    'id': '8100496279',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950338',
#    'task_id': '8909394141',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8Qpgqcrp6vg4G',
#    'v2_task_id': '6XM8QqGPmgj6J42p'},
#   {'completed_at': '2025-02-23T19:59:24.000000Z',
#    'content': '[x] PARA',
#    'id': '8100496259',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950338',
#    'task_id': '8909394134',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8Qpgqcrp6vg4G',
#    'v2_task_id': '6XM8QqJW7HJgRW3G'},
#   {'completed_at': '2025-02-23T19:59:23.000000Z',
#    'content': '[x] GTD',
#    'id': '8100496233',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950338',
#    'task_id': '8909394126',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8Qpgqcrp6vg4G',
#    'v2_task_id': '6XM8Qq94F55FHM4G'},
#   {'completed_at': '2025-02-23T19:59:23.000000Z',
#    'content': '[x] Zettle in obsidian',
#    'id': '8100496215',
#    'item_object': None,
#    'meta_data': None,
#    'note_count': 0,
#    'notes': [],
#    'project_id': '2349449389',
#    'section_id': '183950338',
#    'task_id': '8909394118',
#    'user_id': '40207464',
#    'v2_project_id': '6XM8PgVG3WjHvrmG',
#    'v2_section_id': '6XM8Qpgqcrp6vg4G',
#    'v2_task_id': '6XM8Qq9MjRVqXvHG'}],
#  'projects': {},
#  'sections': {'183950338': {'added_at': '2025-02-23T19:58:43.044500Z',
#    'archived_at': None,
#    'collapsed': False,
#    'id': '183950338',
#    'is_archived': False,
#    'is_deleted': False,
#    'name': 'Education',
#    'project_id': '2349449389',
#    'section_order': 1,
#    'sync_id': None,
#    'updated_at': '2025-02-23T19:58:36.250634Z',
#    'user_id': '40207464',
#    'v2_id': '6XM8Qpgqcrp6vg4G',
#    'v2_project_id': '6XM8PgVG3WjHvrmG'},
#   '183950431': {'added_at': '2025-02-23T19:59:35.081200Z',
#    'archived_at': None,
#    'collapsed': False,
#    'id': '183950431',
#    'is_archived': False,
#    'is_deleted': False,
#    'name': 'Vault',
#    'project_id': '2349449389',
#    'section_order': 2,
#    'sync_id': None,
#    'updated_at': '2025-02-23T19:59:28.387992Z',
#    'user_id': '40207464',
#    'v2_id': '6XM8QxJRWH3r2QwG',
#    'v2_project_id': '6XM8PgVG3WjHvrmG'},
#   '183959614': {'added_at': '2025-02-23T21:52:07.076900Z',
#    'archived_at': None,
#    'collapsed': False,
#    'id': '183959614',
#    'is_archived': False,
#    'is_deleted': False,
#    'name': 'Integrations',
#    'project_id': '2349449389',
#    'section_order': 3,
#    'sync_id': None,
#    'updated_at': '2025-02-23T21:52:00.328374Z',
#    'user_id': '40207464',
#    'v2_id': '6XM94h2XWMw2RqWp',
#    'v2_project_id': '6XM8PgVG3WjHvrmG'},
#   '183962638': {'added_at': '2025-02-23T22:36:56.062900Z',
#    'archived_at': None,
#    'collapsed': False,
#    'id': '183962638',
#    'is_archived': False,
#    'is_deleted': False,
#    'name': 'Plugins/maybe',
#    'project_id': '2349449389',
#    'section_order': 5,
#    'sync_id': None,
#    'updated_at': '2025-02-23T22:37:35.408771Z',
#    'user_id': '40207464',
#    'v2_id': '6XM9G7jvvXwqW5pp',
#    'v2_project_id': '6XM8PgVG3WjHvrmG'},
#   '183962656': {'added_at': '2025-02-23T22:37:43.003200Z',
#    'archived_at': None,
#    'collapsed': False,
#    'id': '183962656',
#    'is_archived': False,
#    'is_deleted': False,
#    'name': 'Plugins',
#    'project_id': '2349449389',
#    'section_order': 4,
#    'sync_id': None,
#    'updated_at': '2025-02-23T22:37:35.238962Z',
#    'user_id': '40207464',
#    'v2_id': '6XM9GFwJv7P8x55p',
#    'v2_project_id': '6XM8PgVG3WjHvrmG'}}}
